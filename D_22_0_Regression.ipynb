# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("https://raw.githubusercontent.com/singhrau0/Big-Data-Preprocessing/main/bostandata%20(1).csv")

# %%
oj = np.zeros(len(list(X.columns)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 oj = np.zeros(len(list(X.columns)))
#
# NameError: name 'X' is not defined

# %%
X = pd.DataFrame({'X1':[1,2,3],'X2':[10,20,30]})

# %%
for k in X.values:
    sum1 = 0
    for l in range(len(k)):
        sum1 = sum1+oj[l]*k[l]
    print(sum1)
# Out:
# 0.0
# 0.0
# 0.0

# %%
oj = np.zeros(len(list(X.columns)))

# %%
oj = [0.5,0.2]

# %%
X["X3"] = [30,40,50]

# %%
y = [1,2,3]

# %%
oj = [0.1,0.2,0.3]

# %%
mysum1(oj,X,0,y,0.001)
# Out:
# 0.00834
# -0.0065999999999999965
# -0.02319999999999999
# [0.00834, -0.0065999999999999965, -0.02319999999999999]
# ([0.00834, -0.0065999999999999965, -0.02319999999999999],
#  -0.00027666666666666665)

# %%
len(X.columns)

# %%
def mysum2(ho0,sum1,y,x1):
    sum2 = 0
    for j in x1:
        sum2 = sum2+(ho0+sum1)*j
    doj = sum2/len(x1)
    return doj

# %%
def mysum1(oj,X,o0,y,a):
    mylist = []
    for k in X.values:
        sum1 = 0
        for l in range(len(k)):
            sum1 = sum1+oj[l]*k[l]
    for i in range(len(X.columns)):
        val = mysum2(o0,sum1,y,X.iloc[:,i])
        dop = oj[i]-(a*val)
        print(dop)
        mylist.append(dop)
    print(mylist)
    ho0 = (o0+sum1)
    do0 = ho0/len(y)
    do0 = o0-(0.001*do0)
    return mylist,do0
def mysum2(ho0,sum1,y,x1):
    sum2 = 0
    for j in x1:
        sum2 = sum2+(ho0+sum1)*j
    doj = sum2/len(x1)
    return doj
alp = 0.001
X
y
oj = list(np.zeros(len(X.columns))+0.01)
print(oj)
# Out:
# [0.01, 0.01, 0.01]

# %%
x1 = [1,3,5,7,9,11,13]
x2 = [2,5,7,6,11,14,15]
y =  [15,17,11,16,18,24]

# %%
j = np.array([[1,2],[3,4],[6,7]])
j
# Out:
# array([[1, 2],
#        [3, 4],
#        [6, 7]])

# %%
a = 0.01
oj = np.zeros(len(list(X.columns)))
o2 = 0
o1 = 0
o0 = 0
for i in range(2000):
    sum1 = 0
    sum2 = 0
    sum3 = 0
    for j,k,p in zip(x1,x2,y):
        sum1 = sum1+((o0+(o1*j)+(o2*k))-p)*j  #o1
        sum2 = sum2+((o0+(o1*j)+(o2*k))-p)*k #o2
        sum3 = sum3+((o0+(o1*j)+(o2*k))-p) #o0
    do1 = sum1/len(x1)
    do2 = sum2/len(x2)
    do0 = sum3/len(x1)
    o1 = o1 - (a*do1)
    o2 = o2 - (a*do2)
    o0 = o0 - (a*do0)
    print(o1,o2,o0)
# Out:
# 0.009414285714285714 0.011742857142857143 0.0014428571428571429
# 0.018731154285714285 0.023365816326530613 0.0028732000000000002
# 0.02795160452012828 0.03487010673547522 0.004291156821586007
# 0.0370766249833348 0.04625694495221171 0.005696854542918142
# 0.04610719410608914 0.05752753508652525 0.007090418797925184
# 0.05504428028800212 0.06868306890333936 0.00847197393250375
# 0.06388884200038215 0.0797247259492788 0.00984164301772356
# 0.07264182788802291 0.09065367367793496 0.011199547862897308
# 0.08130417686994745 0.1014710675738469 0.012545809028516547
# 0.0898768182391195 0.11217805127521142 0.013880545839054941
# 0.09836067176113246 0.12277575669533503 0.015203876395640269
# 0.10675664777188663 0.13326530414284066 0.01651591758859649
# 0.11506564727426499 0.14364780244064215 0.017816785109857243
# 0.12328856203381788 0.15392434904369887 0.019106593465252078
# 0.13142627467346668 0.16409603015556307 0.020385455986666714
# ...

# %%
def mysum1(oj,X,o0,y,a):
    mylist = []
    for k in X.values:
        sum1 = 0
        for l in range(len(k)):
            sum1 = sum1+oj[l]*k[l]
    for i in range(len(X.columns)):
        val = mysum2(o0,sum1,y,X.iloc[:,i])
        dop = oj[i]-(a*val)
        print(dop)
        mylist.append(dop)
    print(mylist)
    ho0 = (o0+sum1)
    do0 = ho0/len(y)
    do0 = o0-(0.001*do0)
    return mylist,do0
def mysum2(ho0,sum1,y,x1):
    sum2 = 0
    for j in x1:
        sum2 = sum2+(ho0+sum1)*j
    doj = sum2/len(x1)
    return doj
alp = 0.001
X
y
oj = list(np.zeros(len(X.columns))+0.01)
print(oj)
